# %% [markdown]
# ### `Importing and observing the Data set`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('microbes.csv')
df.head(5)
# Out:
#    Unnamed: 0  Solidity  Eccentricity  EquivDiameter  Extrema  FilledArea  \
# 0           0     10.70          15.8           5.43     3.75       0.785
# 1           1      5.60          18.3           4.14     6.16       0.364
# 2           2      8.32          19.8           4.63     6.66       0.415
# 3           3     10.10          17.9           7.29    11.10       1.470
# 4           4      6.27          20.2          20.10    10.70      14.700
#
#    Extent  Orientation  EulerNumber  BoundingBox1  ...  ConvexHull4  \
# 0    8.14         2.15         22.3          2.97  ...         2.97
# 1    3.51        18.60         22.5          5.41  ...         5.47
# 2    5.85        21.00         22.4          5.96  ...         5.96
# 3    6.30         9.94         21.9          8.81  ...         8.88
# 4    3.97         2.58         11.9         10.20  ...        10.20
#
#    MajorAxisLength  MinorAxisLength  Perimeter  ConvexArea  Centroid1  \
# ...

# %%
df.shape
# Out:
# (30527, 26)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Solidity', 'Eccentricity', 'EquivDiameter', 'Extrema',
#        'FilledArea', 'Extent', 'Orientation', 'EulerNumber', 'BoundingBox1',
#        'BoundingBox2', 'BoundingBox3', 'BoundingBox4', 'ConvexHull1',
#        'ConvexHull2', 'ConvexHull3', 'ConvexHull4', 'MajorAxisLength',
#        'MinorAxisLength', 'Perimeter', 'ConvexArea', 'Centroid1', 'Centroid2',
#        'Area', 'raddi', 'microorganisms'],
#       dtype='object')

# %% [markdown]
# ### `-----------------------Dataset Columns Dictionary-----------------------`:
# ##### 1. `'Solidity'`: is the firmness and strength of the microbe.
# ##### 2. `'Eccentricity'`: is the ratio of the length of the major to the minor axis of microbes. It shows the circular or eccentric behaviour.
# ##### 3. `'EquivDiameter'`: Diameter of a microbe with the same area as the region
# ##### 4. `'Extrema'`,       'FilledArea', 'Extent', 'Orientation', 'EulerNumber', 'BoundingBox1','BoundingBox2', 'BoundingBox3', 'BoundingBox4'ConvexHull1','ConvexHull2', 'ConvexHull3', 'ConvexHull4', 'MajorAxisLength','MinorAxisLength', 'Perimeter', 'ConvexArea', 'Centroid1', 'Centroid2','Area', 'raddi': they are the geometrics of the microbes which we get under microscopes or by using some softwares which works on the base of OpenCV algorithms.

# %%
df['microorganisms'].unique()
# Out:
# array(['Spirogyra', 'Volvox', 'Pithophora', 'Yeast', 'Raizopus',
#        'Penicillum', 'Aspergillus sp', 'Protozoa', 'Diatom', 'Ulothrix'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Solidity           0
# Eccentricity       0
# EquivDiameter      0
# Extrema            0
# FilledArea         0
# Extent             0
# Orientation        0
# EulerNumber        0
# BoundingBox1       0
# BoundingBox2       0
# BoundingBox3       0
# BoundingBox4       0
# ConvexHull1        0
# ConvexHull2        0
# ConvexHull3        0
# ConvexHull4        0
# MajorAxisLength    0
# MinorAxisLength    0
# Perimeter          0
# ConvexArea         0
# Centroid1          0
# Centroid2          0
# Area               0
# raddi              0
# microorganisms     0
# dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(df,x='microorganisms',y='Solidity') # showing which microbe is more efficient and stronger.
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))
sns.barplot(df,x='microorganisms',y='Eccentricity')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))
sns.barplot(df,x='microorganisms',y='Area')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Solidity', 'Eccentricity', 'EquivDiameter', 'Extrema',
#        'FilledArea', 'Extent', 'Orientation', 'EulerNumber', 'BoundingBox1',
#        'BoundingBox2', 'BoundingBox3', 'BoundingBox4', 'ConvexHull1',
#        'ConvexHull2', 'ConvexHull3', 'ConvexHull4', 'MajorAxisLength',
#        'MinorAxisLength', 'Perimeter', 'ConvexArea', 'Centroid1', 'Centroid2',
#        'Area', 'raddi', 'microorganisms'],
#       dtype='object')

# %% [markdown]
# ### `Creating new Dataframe for predicting accurate microorganism:`

# %%
df1 = df[['Solidity','MajorAxisLength','Perimeter','Area','microorganisms']]

# %%
df1.head(5)
# Out:
#    Solidity  MajorAxisLength  Perimeter    Area microorganisms
# 0     10.70             1.34      0.683   1.310      Spirogyra
# 1      5.60             1.52      1.010   0.765      Spirogyra
# 2      8.32             1.63      1.110   0.953      Spirogyra
# 3     10.10             2.04      0.715   2.340      Spirogyra
# 4      6.27             7.78      6.800  17.600      Spirogyra

# %% [markdown]
# ##### I selected 4 major factors which are very informative in predicting the accurate microbe;
# ##### `Importance of 4 Factors:`
# ##### 1. Solidity : Helps differentiate microorganisms based on their compactness and presence of concavities.
# ##### 2. MajorAxisLength : Useful for understanding the elongation and orientation of microorganisms.
# ##### 3. Perimeter : Helps in differentiating microorganisms with similar areas but different shapes.
# ##### 4. Area : A fundamental measure that gives an indication of the size of the microorganism.

# %%
df1.isnull().sum()
# Out:
# Solidity           0
# MajorAxisLength    0
# Perimeter          0
# Area               0
# microorganisms     0
# dtype: int64

# %%
df1.shape
# Out:
# (30527, 5)

# %%
df1.describe()
# Out:
#            Solidity  MajorAxisLength     Perimeter         Area
# count  30527.000000     30527.000000  30527.000000  30527.00000
# mean       9.677744         1.605159      0.829416      0.80278
# std        4.063437         1.662537      1.152165      1.17043
# min        0.000000         0.000000      0.000000      0.00000
# 25%        6.570000         0.635000      0.253000      0.21800
# 50%        9.350000         1.160000      0.518000      0.51400
# 75%       12.600000         2.070000      0.968000      0.93400
# max       23.000000        23.000000     23.000000     23.00000

# %%
df1['Area'].nunique()
# Out:
# 1525

# %%
df1['MajorAxisLength'].nunique()
# Out:
# 1298

# %%
df1['Perimeter'].nunique()
# Out:
# 1414

# %%
df1['Solidity'].nunique()
# Out:
# 883

# %%
df1['microorganisms'].nunique()
# Out:
# 10

# %%
plt.figure(figsize=(12,6))
sns.barplot(df1,x='microorganisms',y='Area')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))
sns.barplot(df1,x='microorganisms',y='Solidity')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))
sns.barplot(df1,x='microorganisms',y='MajorAxisLength')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))
sns.barplot(df1,x='microorganisms',y='Perimeter')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(df1,x='microorganisms',y='MajorAxisLength')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Training Machine learning model for predicting microorganism

# %%
X = df[['Area','Solidity','MajorAxisLength','Perimeter']]
Y = df['microorganisms']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
df1.describe()
# Out:
#            Solidity  MajorAxisLength     Perimeter         Area
# count  30527.000000     30527.000000  30527.000000  30527.00000
# mean       9.677744         1.605159      0.829416      0.80278
# std        4.063437         1.662537      1.152165      1.17043
# min        0.000000         0.000000      0.000000      0.00000
# 25%        6.570000         0.635000      0.253000      0.21800
# 50%        9.350000         1.160000      0.518000      0.51400
# 75%       12.600000         2.070000      0.968000      0.93400
# max       23.000000        23.000000     23.000000     23.00000

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.9855879462823453

# %%
def predict_microorganism(Solidity,Area,MajorAxisLength,Perimeter):
    
    x = np.zeros(len(X.columns))
    x[0] = Solidity
    x[1] = Area
    x[2] = MajorAxisLength
    x[3] = Perimeter

    return model.predict([x])[0],

# %%
predict_microorganism(10,6.98,2.98,9)
# Out:
# c:\Users\U\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ('Aspergillus sp',)
